# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Demonstrate the PMTarray functionalities

# %%
import pmtarray

# %%
array = pmtarray.PMTarray(array_diameter=2600,
                          border_margin=-10,
                          intra_pmt_distance= 10.,
                          pmt_model='3in')

array.print_properties()
array.plot_pmt_array()
# Out:
# Array diameter: 2600 mm
# Margin from the array edge: -10 mm
# Number of units: 805
# Total array area: 5309291.58 mm^2
# Total photosensor area: 3651850.13 mm^2
# Total PMT active area: 2589677.66 mm^2
# PMT coverage: 0.49

# %%
array = pmtarray.PMTarray(array_diameter=2600,
                          border_margin=-10,
                          intra_pmt_distance= 10.,
                          pmt_model='2in')

array.print_properties()
array.plot_pmt_array()
# Out:
# Array diameter: 2600 mm
# Margin from the array edge: -10 mm
# Number of units: 1147
# Total array area: 5309291.58 mm^2
# Total photosensor area: 3674483.32 mm^2
# Total PMT active area: 2698030.75 mm^2
# PMT coverage: 0.51

# %%
import numpy as np

# %%
centres = np.vstack((array.hex_array_centers_x, 
                     array.hex_array_centers_y))
