# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## PMT unit models and properties

# %%
import pmtarray

# %%
pmtarray.models.model_lib.keys()
# Out:
# dict_keys(['3"', '3in', '2"', '2in'])

# %%
pmt = pmtarray.PMTunit(model = '3in')

pmt.print_properties()
pmt.plot_model()
# Out:
# ---------------------------
# Model: R11410, 3" PMT by Hamamatsu
# ---------------------------
# Diameter: 76 mm
# Active diameter: 64 mm
# Diameter tolerance: 2.6 mm
# ---------------------------
# Total unit area: 4536.46 mm^2
# Active area geometric correction: 1.00
# Active area: 3216.99 mm^2
# Active area fraction: 0.71

# %%
pmt = pmtarray.PMTunit(model = '2in')

pmt.print_properties()
pmt.plot_model()
# Out:
# ---------------------------
# Model: R12699, 2" square PMT by Hamamatsu
# ---------------------------
# Width: 56 mm
# Height: 56 mm
# Active width: 48.5 mm
# Active height: 48.5 mm
# Width tolerance: 0.3 mm
# Height tolerance: 0.3 mm
# ---------------------------
# Total unit area: 3203.56 mm^2
# Active area geometric correction: 1.00
# Active area: 2352.25 mm^2
# Active area fraction: 0.73
